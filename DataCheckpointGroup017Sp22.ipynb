# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Nilou Shahbandi
# - Leonardo Gonzalez
# - Brian Chen
# - Tin-Trung Pham
# - Zhongkang(ken) Fang

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:
# - Link to the dataset:
# - Number of observations:
#
# 1-2 sentences describing each dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
## YOUR CODE HERE
import pandas as pd 
import numpy as ny 

# Data: https://www.americashealthrankings.org/explore/annual/measure/air/state/ALL 
df = pd.read_csv('data/2021-Annual.csv')
df
# Out:
#        Edition  Report Type             Measure Name     State Name  Rank  \
# 0         2021  2021 Annual  Access to Care - Annual         Alaska  20.0
# 1         2021  2021 Annual  Access to Care - Annual        Alabama  45.0
# 2         2021  2021 Annual  Access to Care - Annual       Arkansas  43.0
# 3         2021  2021 Annual  Access to Care - Annual        Arizona  42.0
# 4         2021  2021 Annual  Access to Care - Annual     California  18.0
# ...        ...          ...                      ...            ...   ...
# 52414     2021  2021 Annual       Water Fluoridation        Vermont  40.0
# 52415     2021  2021 Annual       Water Fluoridation     Washington  34.0
# 52416     2021  2021 Annual       Water Fluoridation      Wisconsin  18.0
# 52417     2021  2021 Annual       Water Fluoridation  West Virginia  12.0
# 52418     2021  2021 Annual       Water Fluoridation        Wyoming  39.0
#
#         Value  Score  Lower CI  Upper CI    Source  Source Year
# ...

# %%
# https://aqs.epa.gov/aqsweb/airdata/download_files.html #Annual AQI
aqi = pd.read_csv('data/AQI.csv')
#aqi.columns = aqi.columns.str.replace(' ', '')
aqi.columns = aqi.columns.str.lower()
aqi.head()
states = aqi.groupby(['state']).agg('mean')
#states.shape
states
# Out:
#                         year  days with aqi   good days  moderate days  \
# state
# Alabama               2021.0     207.428571  172.785714      34.142857
# Alaska                2021.0     197.200000  173.800000      19.000000
# Arizona               2021.0     271.692308  168.615385      87.538462
# Arkansas              2021.0     186.272727  152.181818      33.454545
# California            2021.0     226.098039  144.117647      67.647059
# Colorado              2021.0     215.640000  142.560000      60.000000
# Connecticut           2021.0     172.000000  143.625000      25.375000
# Country Of Mexico     2021.0     304.000000   44.000000     226.000000
# Delaware              2021.0     149.333333  122.666667      26.333333
# District Of Columbia  2021.0     274.000000  174.000000      90.000000
# Florida               2021.0     183.461538  160.487179      22.846154
# Georgia               2021.0     220.285714  179.892857      39.142857
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
